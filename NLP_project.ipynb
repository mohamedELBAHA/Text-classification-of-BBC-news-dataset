# %%
import csv
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/bbc-text.csv \
    -O /tmp/bbc-text.csv
# Out:
# --2021-04-13 10:32:53--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/bbc-text.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.13.128, 142.251.5.128, 74.125.206.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.13.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5057493 (4.8M) [application/octet-stream]
# Saving to: ‘/tmp/bbc-text.csv’
#
# /tmp/bbc-text.csv   100%[===================>]   4.82M  --.-KB/s    in 0.05s
#
# 2021-04-13 10:32:53 (107 MB/s) - ‘/tmp/bbc-text.csv’ saved [5057493/5057493]

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_portion = .8

# %%
sentences = []
labels = []
stopwords = [ "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]
print(len(stopwords))
# Out:
# 153

# %%
with open("/tmp/bbc-text.csv", 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        sentence = row[1]
        for word in stopwords:
            token = " " + word + " "
            sentence = sentence.replace(token, " ")
        sentences.append(sentence)

print(len(labels))
print(len(sentences))
print(sentences[0])
# Out:
# 2225
# 2225
# tv future hands viewers home theatre systems  plasma high-definition tvs  digital video recorders moving living room  way people watch tv will radically different five years  time.  according expert panel gathered annual consumer electronics show las vegas discuss new technologies will impact one favourite pastimes. us leading trend  programmes content will delivered viewers via home networks  cable  satellite  telecoms companies  broadband service providers front rooms portable devices.  one talked-about technologies ces digital personal video recorders (dvr pvr). set-top boxes  like us s tivo uk s sky+ system  allow people record  store  play  pause forward wind tv programmes want.  essentially  technology allows much personalised tv. also built-in high-definition tv sets  big business japan us  slower take off europe lack high-definition programming. not can people forward wind adverts  can also forget abiding network channel schedules  putting together a-la-carte entertainment. us networks cable satellite companies worried means terms advertising revenues well  brand identity  viewer loyalty channels. although us leads technology moment  also concern raised europe  particularly growing uptake services like sky+.  happens today  will see nine months years  time uk   adam hume  bbc broadcast s futurologist told bbc news website. likes bbc  no issues lost advertising revenue yet. pressing issue moment commercial uk broadcasters  brand loyalty important everyone.  will talking content brands rather network brands   said tim hanlon  brand communications firm starcom mediavest.  reality broadband connections  anybody can producer content.  added:  challenge now hard promote programme much choice.   means  said stacey jolna  senior vice president tv guide tv group  way people find content want watch simplified tv viewers. means networks  us terms  channels take leaf google s book search engine future  instead scheduler help people find want watch. kind channel model might work younger ipod generation used taking control gadgets play them. might not suit everyone  panel recognised. older generations comfortable familiar schedules channel brands know getting. perhaps not want much choice put hands  mr hanlon suggested.  end  kids just diapers pushing buttons already - everything possible available   said mr hanlon.  ultimately  consumer will tell market want.   50 000 new gadgets technologies showcased ces  many enhancing tv-watching experience. high-definition tv sets everywhere many new models lcd (liquid crystal display) tvs launched dvr capability built  instead external boxes. one example launched show humax s 26-inch lcd tv 80-hour tivo dvr dvd recorder. one us s biggest satellite tv companies  directtv  even launched branded dvr show 100-hours recording capability  instant replay  search function. set can pause rewind tv 90 hours. microsoft chief bill gates announced pre-show keynote speech partnership tivo  called tivotogo  means people can play recorded programmes windows pcs mobile devices. reflect increasing trend freeing multimedia people can watch want  want.

# %%
train_size = int(len(sentences) * training_portion)

train_sentences = sentences[:train_size]
train_labels = labels[:train_size]

validation_sentences = sentences[train_size:]
validation_labels = labels[train_size:]

print("train_size :", train_size)
print("len(train_sentences) = ",len(train_sentences))
print("len(train_labels) = ", len(train_labels))
print("len(validation_sentences) = ",len(validation_sentences))
print("len(validation_labels) = ",len(validation_labels))
# Out:
# train_size : 1780
# len(train_sentences) =  1780
# len(train_labels) =  1780
# len(validation_sentences) 445
# len(validation_labels) 445

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_sentences)
word_index = tokenizer.word_index

train_sequences = tokenizer.texts_to_sequences(train_sentences)
train_padded = pad_sequences(train_sequences, padding=padding_type, maxlen=max_length)

print(len(train_sequences[0]))
print(len(train_padded[0]))

print(len(train_sequences[1]))
print(len(train_padded[1]))

print(len(train_sequences[10]))
print(len(train_padded[10]))
# Out:
# 449
# 120
# 200
# 120
# 192
# 120

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_sentences)
validation_padded = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)

print(len(validation_sequences))
print(validation_padded.shape)
# Out:
# 445
# (445, 120)

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

print(training_label_seq[0])
print(training_label_seq[1])
print(training_label_seq[2])
print(training_label_seq.shape)

print(validation_label_seq[0])
print(validation_label_seq[1])
print(validation_label_seq[2])
print(validation_label_seq.shape)
# Out:
# [4]
# [2]
# [1]
# (1780, 1)
# [5]
# [4]
# [3]
# (445, 1)

# %%
model_64_dense = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
model_64_dense.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model_64_dense.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           16000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 24)                408
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 150
# =================================================================
# Total params: 16,558
# Trainable params: 16,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = model_64_dense.fit(train_padded, training_label_seq, epochs=num_epochs, validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/30
# 56/56 - 4s - loss: 1.7544 - accuracy: 0.2697 - val_loss: 1.7122 - val_accuracy: 0.2292
# Epoch 2/30
# 56/56 - 0s - loss: 1.6586 - accuracy: 0.2989 - val_loss: 1.6078 - val_accuracy: 0.3798
# Epoch 3/30
# 56/56 - 0s - loss: 1.5460 - accuracy: 0.4022 - val_loss: 1.4912 - val_accuracy: 0.4584
# Epoch 4/30
# 56/56 - 0s - loss: 1.4036 - accuracy: 0.5051 - val_loss: 1.3252 - val_accuracy: 0.6000
# Epoch 5/30
# 56/56 - 0s - loss: 1.2108 - accuracy: 0.6719 - val_loss: 1.1295 - val_accuracy: 0.7146
# Epoch 6/30
# 56/56 - 0s - loss: 1.0085 - accuracy: 0.7511 - val_loss: 0.9499 - val_accuracy: 0.7865
# Epoch 7/30
# 56/56 - 0s - loss: 0.8332 - accuracy: 0.8635 - val_loss: 0.8014 - val_accuracy: 0.8697
# Epoch 8/30
# 56/56 - 0s - loss: 0.6949 - accuracy: 0.9028 - val_loss: 0.6891 - val_accuracy: 0.8854
# Epoch 9/30
# 56/56 - 0s - loss: 0.5816 - accuracy: 0.9247 - val_loss: 0.5964 - val_accuracy: 0.8854
# Epoch 10/30
# 56/56 - 0s - loss: 0.4878 - accuracy: 0.9320 - val_loss: 0.5205 - val_accuracy: 0.8944
# Epoch 11/30
# 56/56 - 0s - loss: 0.4094 - accuracy: 0.9449 - val_loss: 0.4601 - val_accuracy: 0.9056
# Epoch 12/30
# 56/56 - 0s - loss: 0.3453 - accuracy: 0.9551 - val_loss: 0.4102 - val_accuracy: 0.9101
# Epoch 13/30
# 56/56 - 0s - loss: 0.2934 - accuracy: 0.9612 - val_loss: 0.3716 - val_accuracy: 0.9146
# Epoch 14/30
# 56/56 - 0s - loss: 0.2519 - accuracy: 0.9624 - val_loss: 0.3392 - val_accuracy: 0.9169
# Epoch 15/30
# 56/56 - 0s - loss: 0.2185 - accuracy: 0.9697 - val_loss: 0.3144 - val_accuracy: 0.9213
# Epoch 16/30
# 56/56 - 0s - loss: 0.1911 - accuracy: 0.9742 - val_loss: 0.2968 - val_accuracy: 0.9213
# Epoch 17/30
# 56/56 - 0s - loss: 0.1671 - accuracy: 0.9758 - val_loss: 0.2787 - val_accuracy: 0.9191
# Epoch 18/30
# 56/56 - 0s - loss: 0.1481 - accuracy: 0.9792 - val_loss: 0.2654 - val_accuracy: 0.9258
# Epoch 19/30
# 56/56 - 0s - loss: 0.1320 - accuracy: 0.9826 - val_loss: 0.2555 - val_accuracy: 0.9213
# Epoch 20/30
# 56/56 - 0s - loss: 0.1174 - accuracy: 0.9848 - val_loss: 0.2423 - val_accuracy: 0.9303
# Epoch 21/30
# 56/56 - 0s - loss: 0.1054 - accuracy: 0.9899 - val_loss: 0.2341 - val_accuracy: 0.9258
# Epoch 22/30
# 56/56 - 0s - loss: 0.0950 - accuracy: 0.9893 - val_loss: 0.2272 - val_accuracy: 0.9348
# Epoch 23/30
# 56/56 - 0s - loss: 0.0852 - accuracy: 0.9933 - val_loss: 0.2258 - val_accuracy: 0.9348
# Epoch 24/30
# 56/56 - 0s - loss: 0.0772 - accuracy: 0.9949 - val_loss: 0.2156 - val_accuracy: 0.9326
# Epoch 25/30
# 56/56 - 0s - loss: 0.0697 - accuracy: 0.9955 - val_loss: 0.2121 - val_accuracy: 0.9393
# Epoch 26/30
# 56/56 - 0s - loss: 0.0634 - accuracy: 0.9955 - val_loss: 0.2099 - val_accuracy: 0.9371
# Epoch 27/30
# 56/56 - 0s - loss: 0.0573 - accuracy: 0.9972 - val_loss: 0.2028 - val_accuracy: 0.9416
# Epoch 28/30
# 56/56 - 0s - loss: 0.0522 - accuracy: 0.9978 - val_loss: 0.2049 - val_accuracy: 0.9371
# Epoch 29/30
# 56/56 - 0s - loss: 0.0477 - accuracy: 0.9983 - val_loss: 0.2009 - val_accuracy: 0.9371
# Epoch 30/30
# 56/56 - 0s - loss: 0.0435 - accuracy: 0.9983 - val_loss: 0.1982 - val_accuracy: 0.9393

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
model_32_LSTM = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.LSTM(32),
    #tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
model_32_LSTM.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model_32_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           16000
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                6272
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 22,470
# Trainable params: 22,470
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model_32_LSTM.fit(train_padded, training_label_seq, epochs=60, validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/60
# 56/56 - 30s - loss: 1.6881 - accuracy: 0.2253 - val_loss: 1.6098 - val_accuracy: 0.3146
# Epoch 2/60
# 56/56 - 1s - loss: 1.6022 - accuracy: 0.2747 - val_loss: 1.5920 - val_accuracy: 0.2876
# Epoch 3/60
# 56/56 - 1s - loss: 1.5057 - accuracy: 0.3820 - val_loss: 1.3574 - val_accuracy: 0.3573
# Epoch 4/60
# 56/56 - 1s - loss: 1.6049 - accuracy: 0.3247 - val_loss: 1.5022 - val_accuracy: 0.3775
# Epoch 5/60
# 56/56 - 1s - loss: 1.4073 - accuracy: 0.4169 - val_loss: 1.5746 - val_accuracy: 0.2742
# Epoch 6/60
# 56/56 - 1s - loss: 1.4057 - accuracy: 0.4674 - val_loss: 1.3862 - val_accuracy: 0.4539
# Epoch 7/60
# 56/56 - 1s - loss: 1.4702 - accuracy: 0.4000 - val_loss: 1.2764 - val_accuracy: 0.4809
# Epoch 8/60
# 56/56 - 1s - loss: 1.2329 - accuracy: 0.4652 - val_loss: 1.2010 - val_accuracy: 0.5146
# Epoch 9/60
# 56/56 - 1s - loss: 1.3271 - accuracy: 0.4343 - val_loss: 1.1900 - val_accuracy: 0.5213
# Epoch 10/60
# 56/56 - 1s - loss: 1.1480 - accuracy: 0.5820 - val_loss: 1.1050 - val_accuracy: 0.5843
# Epoch 11/60
# 56/56 - 1s - loss: 0.9157 - accuracy: 0.6247 - val_loss: 0.9547 - val_accuracy: 0.6562
# Epoch 12/60
# 56/56 - 1s - loss: 0.7429 - accuracy: 0.7837 - val_loss: 0.8080 - val_accuracy: 0.7438
# Epoch 13/60
# 56/56 - 1s - loss: 0.5551 - accuracy: 0.8579 - val_loss: 0.6401 - val_accuracy: 0.7955
# Epoch 14/60
# 56/56 - 1s - loss: 0.4731 - accuracy: 0.8652 - val_loss: 0.6108 - val_accuracy: 0.8135
# Epoch 15/60
# 56/56 - 1s - loss: 0.5166 - accuracy: 0.8365 - val_loss: 0.6657 - val_accuracy: 0.7775
# Epoch 16/60
# 56/56 - 1s - loss: 0.3632 - accuracy: 0.9039 - val_loss: 0.5425 - val_accuracy: 0.8067
# Epoch 17/60
# 56/56 - 1s - loss: 0.3354 - accuracy: 0.9073 - val_loss: 0.7082 - val_accuracy: 0.7663
# Epoch 18/60
# 56/56 - 1s - loss: 0.4148 - accuracy: 0.8528 - val_loss: 0.5193 - val_accuracy: 0.8337
# Epoch 19/60
# 56/56 - 1s - loss: 0.2996 - accuracy: 0.9039 - val_loss: 0.7851 - val_accuracy: 0.7348
# Epoch 20/60
# 56/56 - 1s - loss: 0.3835 - accuracy: 0.8742 - val_loss: 0.8784 - val_accuracy: 0.6831
# Epoch 21/60
# 56/56 - 1s - loss: 0.4235 - accuracy: 0.8455 - val_loss: 0.6813 - val_accuracy: 0.7730
# Epoch 22/60
# 56/56 - 1s - loss: 0.4562 - accuracy: 0.8624 - val_loss: 0.6642 - val_accuracy: 0.7730
# Epoch 23/60
# 56/56 - 1s - loss: 0.3403 - accuracy: 0.9028 - val_loss: 0.4840 - val_accuracy: 0.8472
# Epoch 24/60
# 56/56 - 1s - loss: 0.2485 - accuracy: 0.9478 - val_loss: 0.4973 - val_accuracy: 0.8517
# Epoch 25/60
# 56/56 - 1s - loss: 0.2384 - accuracy: 0.9360 - val_loss: 0.5631 - val_accuracy: 0.8360
# Epoch 26/60
# 56/56 - 1s - loss: 0.1887 - accuracy: 0.9567 - val_loss: 0.4124 - val_accuracy: 0.8742
# Epoch 27/60
# 56/56 - 1s - loss: 0.1440 - accuracy: 0.9652 - val_loss: 0.4459 - val_accuracy: 0.8809
# Epoch 28/60
# 56/56 - 1s - loss: 0.2891 - accuracy: 0.8994 - val_loss: 0.4766 - val_accuracy: 0.8449
# Epoch 29/60
# 56/56 - 1s - loss: 0.1317 - accuracy: 0.9725 - val_loss: 0.4552 - val_accuracy: 0.8787
# Epoch 30/60
# 56/56 - 1s - loss: 0.1157 - accuracy: 0.9764 - val_loss: 0.4788 - val_accuracy: 0.8629
# Epoch 31/60
# 56/56 - 1s - loss: 0.0993 - accuracy: 0.9803 - val_loss: 0.4208 - val_accuracy: 0.8764
# Epoch 32/60
# 56/56 - 1s - loss: 0.0790 - accuracy: 0.9837 - val_loss: 0.4585 - val_accuracy: 0.8787
# Epoch 33/60
# 56/56 - 1s - loss: 0.0722 - accuracy: 0.9837 - val_loss: 0.4310 - val_accuracy: 0.8899
# Epoch 34/60
# 56/56 - 1s - loss: 0.0658 - accuracy: 0.9848 - val_loss: 0.4278 - val_accuracy: 0.8921
# Epoch 35/60
# 56/56 - 1s - loss: 0.0623 - accuracy: 0.9860 - val_loss: 0.4416 - val_accuracy: 0.8764
# Epoch 36/60
# 56/56 - 1s - loss: 0.0649 - accuracy: 0.9865 - val_loss: 0.4231 - val_accuracy: 0.8742
# Epoch 37/60
# 56/56 - 1s - loss: 0.0618 - accuracy: 0.9882 - val_loss: 0.4429 - val_accuracy: 0.8809
# Epoch 38/60
# 56/56 - 1s - loss: 0.0499 - accuracy: 0.9904 - val_loss: 0.4915 - val_accuracy: 0.8809
# Epoch 39/60
# 56/56 - 1s - loss: 0.0709 - accuracy: 0.9848 - val_loss: 0.4641 - val_accuracy: 0.8899
# Epoch 40/60
# 56/56 - 1s - loss: 0.1053 - accuracy: 0.9747 - val_loss: 0.4695 - val_accuracy: 0.8697
# Epoch 41/60
# 56/56 - 1s - loss: 0.0599 - accuracy: 0.9860 - val_loss: 0.4574 - val_accuracy: 0.8764
# Epoch 42/60
# 56/56 - 1s - loss: 0.0409 - accuracy: 0.9916 - val_loss: 0.4913 - val_accuracy: 0.8764
# Epoch 43/60
# 56/56 - 1s - loss: 0.0386 - accuracy: 0.9927 - val_loss: 0.4159 - val_accuracy: 0.8989
# Epoch 44/60
# 56/56 - 1s - loss: 0.0363 - accuracy: 0.9944 - val_loss: 0.4254 - val_accuracy: 0.8899
# Epoch 45/60
# 56/56 - 1s - loss: 0.0317 - accuracy: 0.9944 - val_loss: 0.4601 - val_accuracy: 0.8944
# Epoch 46/60
# 56/56 - 1s - loss: 0.0295 - accuracy: 0.9949 - val_loss: 0.4713 - val_accuracy: 0.8876
# Epoch 47/60
# 56/56 - 1s - loss: 0.0267 - accuracy: 0.9961 - val_loss: 0.4260 - val_accuracy: 0.8944
# Epoch 48/60
# 56/56 - 1s - loss: 0.0262 - accuracy: 0.9955 - val_loss: 0.4029 - val_accuracy: 0.9011
# Epoch 49/60
# 56/56 - 1s - loss: 0.0234 - accuracy: 0.9966 - val_loss: 0.4629 - val_accuracy: 0.8966
# Epoch 50/60
# 56/56 - 1s - loss: 0.0216 - accuracy: 0.9972 - val_loss: 0.4229 - val_accuracy: 0.9011
# Epoch 51/60
# 56/56 - 1s - loss: 0.0211 - accuracy: 0.9966 - val_loss: 0.4470 - val_accuracy: 0.9034
# Epoch 52/60
# 56/56 - 1s - loss: 0.0218 - accuracy: 0.9966 - val_loss: 0.4326 - val_accuracy: 0.8921
# Epoch 53/60
# 56/56 - 1s - loss: 0.0309 - accuracy: 0.9938 - val_loss: 0.4954 - val_accuracy: 0.8719
# Epoch 54/60
# 56/56 - 1s - loss: 0.3485 - accuracy: 0.8904 - val_loss: 0.7325 - val_accuracy: 0.7618
# Epoch 55/60
# 56/56 - 1s - loss: 0.1989 - accuracy: 0.9511 - val_loss: 0.5371 - val_accuracy: 0.8584
# Epoch 56/60
# 56/56 - 1s - loss: 0.1231 - accuracy: 0.9697 - val_loss: 0.5387 - val_accuracy: 0.8427
# Epoch 57/60
# 56/56 - 1s - loss: 0.0762 - accuracy: 0.9826 - val_loss: 0.4934 - val_accuracy: 0.8697
# Epoch 58/60
# 56/56 - 1s - loss: 0.0687 - accuracy: 0.9826 - val_loss: 0.5072 - val_accuracy: 0.8787
# Epoch 59/60
# 56/56 - 1s - loss: 0.0380 - accuracy: 0.9921 - val_loss: 0.5153 - val_accuracy: 0.8787
# Epoch 60/60
# 56/56 - 1s - loss: 0.0252 - accuracy: 0.9944 - val_loss: 0.5297 - val_accuracy: 0.8876

# %%
plot_graphs(history2, "accuracy")
plot_graphs(history2, "loss")

# %%
model_lstm_conv1d = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(6, activation='softmax')
])
model_lstm_conv1d.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model_lstm_conv1d.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           16000
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 16)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 64)           5184
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 29, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 54,598
# Trainable params: 54,598
# Non-trainable params: 0
# _________________________________________________________________

# %%
history3 = model_lstm_conv1d.fit(train_padded, training_label_seq, epochs=num_epochs, validation_data=(validation_padded, validation_label_seq), verbose=2)
# Out:
# Epoch 1/30
# 56/56 - 4s - loss: 1.6605 - accuracy: 0.2219 - val_loss: 1.6137 - val_accuracy: 0.2360
# Epoch 2/30
# 56/56 - 1s - loss: 1.4724 - accuracy: 0.3933 - val_loss: 0.9999 - val_accuracy: 0.5933
# Epoch 3/30
# 56/56 - 1s - loss: 0.6996 - accuracy: 0.7326 - val_loss: 0.5974 - val_accuracy: 0.7640
# Epoch 4/30
# 56/56 - 1s - loss: 0.3879 - accuracy: 0.8770 - val_loss: 0.4119 - val_accuracy: 0.8652
# Epoch 5/30
# 56/56 - 1s - loss: 0.2377 - accuracy: 0.9236 - val_loss: 0.4378 - val_accuracy: 0.8562
# Epoch 6/30
# 56/56 - 1s - loss: 0.1803 - accuracy: 0.9393 - val_loss: 0.2992 - val_accuracy: 0.8921
# Epoch 7/30
# 56/56 - 1s - loss: 0.1241 - accuracy: 0.9635 - val_loss: 0.3561 - val_accuracy: 0.8719
# Epoch 8/30
# 56/56 - 1s - loss: 0.1124 - accuracy: 0.9663 - val_loss: 0.2547 - val_accuracy: 0.9169
# Epoch 9/30
# 56/56 - 1s - loss: 0.0683 - accuracy: 0.9826 - val_loss: 0.2805 - val_accuracy: 0.9191
# Epoch 10/30
# 56/56 - 1s - loss: 0.0479 - accuracy: 0.9893 - val_loss: 0.3286 - val_accuracy: 0.9056
# Epoch 11/30
# 56/56 - 1s - loss: 0.0374 - accuracy: 0.9916 - val_loss: 0.4066 - val_accuracy: 0.8719
# Epoch 12/30
# 56/56 - 1s - loss: 0.0713 - accuracy: 0.9792 - val_loss: 0.5615 - val_accuracy: 0.8404
# Epoch 13/30
# 56/56 - 1s - loss: 0.0737 - accuracy: 0.9809 - val_loss: 0.3466 - val_accuracy: 0.8989
# Epoch 14/30
# 56/56 - 1s - loss: 0.0361 - accuracy: 0.9899 - val_loss: 0.3302 - val_accuracy: 0.9056
# Epoch 15/30
# 56/56 - 1s - loss: 0.0248 - accuracy: 0.9944 - val_loss: 0.3934 - val_accuracy: 0.8944
# Epoch 16/30
# 56/56 - 1s - loss: 0.0489 - accuracy: 0.9831 - val_loss: 0.4035 - val_accuracy: 0.9034
# Epoch 17/30
# 56/56 - 1s - loss: 0.0448 - accuracy: 0.9876 - val_loss: 0.4999 - val_accuracy: 0.8787
# Epoch 18/30
# 56/56 - 1s - loss: 0.0515 - accuracy: 0.9831 - val_loss: 0.3383 - val_accuracy: 0.9169
# Epoch 19/30
# 56/56 - 1s - loss: 0.0293 - accuracy: 0.9927 - val_loss: 0.3783 - val_accuracy: 0.9034
# Epoch 20/30
# 56/56 - 1s - loss: 0.0156 - accuracy: 0.9966 - val_loss: 0.3729 - val_accuracy: 0.9079
# Epoch 21/30
# 56/56 - 1s - loss: 0.0075 - accuracy: 0.9994 - val_loss: 0.4133 - val_accuracy: 0.9034
# Epoch 22/30
# 56/56 - 1s - loss: 0.0106 - accuracy: 0.9978 - val_loss: 0.4812 - val_accuracy: 0.8944
# Epoch 23/30
# 56/56 - 1s - loss: 0.0178 - accuracy: 0.9966 - val_loss: 0.4137 - val_accuracy: 0.9034
# Epoch 24/30
# 56/56 - 1s - loss: 0.0122 - accuracy: 0.9978 - val_loss: 0.4275 - val_accuracy: 0.9011
# Epoch 25/30
# 56/56 - 1s - loss: 0.0198 - accuracy: 0.9961 - val_loss: 0.3536 - val_accuracy: 0.9079
# Epoch 26/30
# 56/56 - 1s - loss: 0.0296 - accuracy: 0.9904 - val_loss: 0.3044 - val_accuracy: 0.9079
# Epoch 27/30
# 56/56 - 1s - loss: 0.0141 - accuracy: 0.9961 - val_loss: 0.4279 - val_accuracy: 0.9056
# Epoch 28/30
# 56/56 - 1s - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.4713 - val_accuracy: 0.9011
# Epoch 29/30
# 56/56 - 1s - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.4286 - val_accuracy: 0.9079
# Epoch 30/30
# 56/56 - 1s - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.4271 - val_accuracy: 0.9056

# %%
plot_graphs(history3, "accuracy")
plot_graphs(history3, "loss")

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_'+'accuracy'],'--')
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_'+'accuracy'],'--')
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_'+'accuracy'],'--')
plt.xlabel("Epochs")
plt.ylabel('accuracy')
plt.legend(['ANN_train','ANN_val','LSTM_train','LSTM_val','LSTM_Conv1D_train','LSTM_Conv1D_val'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_'+'loss'],'--')
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_'+'loss'],'--')
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_'+'loss'],'--')
plt.xlabel("Epochs")
plt.ylabel('loss')
plt.legend(['ANN_train','ANN_val','LSTM_train','LSTM_val','LSTM_Conv1D_train','LSTM_Conv1D_val'])
plt.show()

# %%
x=model_64_dense.layers[0]
weight1=x.get_weights()[0]
y=model_32_LSTM.layers[0]
weight2=y.get_weights()[0]
z=model_lstm_conv1d.layers[0]
weight3=z.get_weights()[0]
print(weight1.shape)
print(weight2.shape)
print(weight3.shape)
# Out:
# (1000, 16)
# (1000, 16)
# (1000, 16)

# %%
word_index.items()
# Out:
# dict_items([('<OOV>', 1), ('s', 2), ('said', 3), ('will', 4), ('not', 5), ('mr', 6), ('year', 7), ('also', 8), ('people', 9), ('new', 10), ('us', 11), ('one', 12), ('can', 13), ('last', 14), ('t', 15), ('first', 16), ('time', 17), ('two', 18), ('government', 19), ('world', 20), ('now', 21), ('uk', 22), ('best', 23), ('years', 24), ('no', 25), ('make', 26), ('just', 27), ('film', 28), ('told', 29), ('made', 30), ('get', 31), ('music', 32), ('game', 33), ('like', 34), ('back', 35), ('many', 36), ('000', 37), ('labour', 38), ('three', 39), ('well', 40), ('1', 41), ('next', 42), ('bbc', 43), ('take', 44), ('set', 45), ('number', 46), ('added', 47), ('way', 48), ('market', 49), ('2', 50), ('company', 51), ('may', 52), ('says', 53), ('election', 54), ('home', 55), ('off', 56), ('party', 57), ('good', 58), ('going', 59), ('much', 60), ('work', 61), ('2004', 62), ('still', 63), ('win', 64), ('show', 65), ('think', 66), ('games', 67), ('go', 68), ('top', 69), ('second', 70), ('won', 71), ('million', 72), ('6', 73), ('england', 74), ('firm', 75), ('since', 76), ('week', 77), ('say', 78), ('play', 79), ('part', 80), ('public', 81), ('use', 82), ('blair', 83), ('3', 84), ('want', 85), ('minister', 86), ('however', 87), ('10', 88), ('country', 89), ('technology', 90), ('see', 91), ('4', 92), ('five', 93), ('british', 94), ('news', 95), ('european', 96), ('high', 97), ('group', 98), ('tv', 99), ('used', 100), ('end', 101), ('expected', 102), ('even', 103), ('players', 104), ('m', 105), ('brown', 106), ('5', 107), ('six', 108), ('old', 109), ('net', 110), ('already', 111), ('four', 112), ('plans', 113), ('put', 114), ('come', 115), ('half', 116), ('london', 117), ('sales', 118), ('growth', 119), ('don', 120), ('long', 121), ('economy', 122), ('service', 123), ('right', 124), ('months', 125), ('chief', 126), ('day', 127), ('mobile', 128), ('former', 129), ('money', 130), ('britain', 131), ('director', 132), ('tax', 133), ('services', 134), ('2005', 135), ('deal', 136), ('need', 137), ('help', 138), ('digital', 139), ('according', 140), ('big', 141), ('industry', 142), ('place', 143), ('companies', 144), ('users', 145), ('system', 146), ('business', 147), ('including', 148), ('team', 149), ('final', 150), ('based', 151), ('hit', 152), ('record', 153), ('report', 154), ('third', 155), ('called', 156), ('really', 157), ('international', 158), ('month', 159), ('move', 160), ('wales', 161), ('europe', 162), ('another', 163), ('7', 164), ('life', 165), ('around', 166), ('economic', 167), ('start', 168), ('great', 169), ('future', 170), ('2003', 171), ('firms', 172), ('came', 173), ('france', 174), ('open', 175), ('got', 176), ('spokesman', 177), ('software', 178), ('re', 179), ('without', 180), ('general', 181), ('club', 182), ('up', 183), ('took', 184), ('ireland', 185), ('video', 186), ('howard', 187), ('know', 188), ('united', 189), ('online', 190), ('bank', 191), ('phone', 192), ('china', 193), ('far', 194), ('state', 195), ('campaign', 196), ('side', 197), ('law', 198), ('radio', 199), ('better', 200), ('court', 201), ('making', 202), ('decision', 203), ('executive', 204), ('real', 205), ('media', 206), ('offer', 207), ('give', 208), ('computer', 209), ('found', 210), ('action', 211), ('it', 212), ('able', 213), ('president', 214), ('information', 215), ('despite', 216), ('office', 217), ('star', 218), ('lot', 219), ('o', 220), ('national', 221), ('line', 222), ('countries', 223), ('likely', 224), ('using', 225), ('away', 226), ('player', 227), ('internet', 228), ('saying', 229), ('every', 230), ('given', 231), ('security', 232), ('become', 233), ('left', 234), ('awards', 235), ('figures', 236), ('anti', 237), ('nations', 238), ('run', 239), ('eu', 240), ('20', 241), ('cost', 242), ('ve', 243), ('prime', 244), ('role', 245), ('seen', 246), ('playing', 247), ('biggest', 248), ('man', 249), ('january', 250), ('data', 251), ('bill', 252), ('whether', 253), ('played', 254), ('later', 255), ('foreign', 256), ('although', 257), ('cup', 258), ('hard' ...

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %%
from numpy import dot
from numpy.linalg import norm

def cos_sim(a,b):
  return dot(a, b)/(norm(a)*norm(b))

def euc_dist(a,b):
  return np.linalg.norm(a-b)

# %%
import pandas as pd
df=pd.DataFrame(weight1)

# %%
X_corr=df.corr()
values,vectors=np.linalg.eig(X_corr)
eigv_s=(-values).argsort()
vectors=vectors[:,eigv_s]
new_vectors=vectors[:,:2]
new_X=np.dot(weight1,new_vectors)

# %%
import matplotlib.pyplot as plt
vocab_word=list(word_index.keys())
vocab_word=vocab_word[:1000]
random_vocab=np.random.choice(vocab_word,150)
random_index=list(word_index[i] for i in random_vocab)
sampled_X=new_X[random_index,:]
plt.figure(figsize=(13,7))
plt.scatter(sampled_X[:,0],sampled_X[:,1],linewidths=10,color='blue')
plt.xlabel("Dimension 1",size=15)
plt.ylabel("Dimension 2",size=15)
plt.title("Word Embedding Space",size=20)
vocab=len(random_vocab)
for i in range(vocab):
  word=random_vocab[i]
  plt.annotate(word,xy=(sampled_X[i,0],sampled_X[i,1]))
